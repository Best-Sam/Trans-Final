# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\user\Documents\Food Delivery Performance.csv")
df
# Out:
#            ID Delivery_person_ID  Delivery_person_Age  \
# 0      0x2318    COIMBRES13DEL01                  NaN
# 1      0x3474     BANGRES15DEL01                 28.0
# 2      0x9420      JAPRES09DEL03                 23.0
# 3      0x72ee      JAPRES07DEL03                 21.0
# 4      0xa759     CHENRES19DEL01                 31.0
# ...       ...                ...                  ...
# 11394  0x6909      JAPRES01DEL01                 35.0
# 11395  0x443b      JAPRES11DEL01                 33.0
# 11396  0x1ea5      SURRES11DEL03                  NaN
# 11397  0x22d4      VADRES03DEL02                 27.0
# 11398  0xb7be     CHENRES07DEL02                 39.0
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 0                          NaN            11.003669             76.976494
# 1                          4.6            12.975377             77.696664
# 2                          4.5            26.911378             75.789034
# ...

# %%
# Calling out a particular column

df.Delivery_person_Age
# Out:
# 0         NaN
# 1        28.0
# 2        23.0
# 3        21.0
# 4        31.0
#          ...
# 11394    35.0
# 11395    33.0
# 11396     NaN
# 11397    27.0
# 11398    39.0
# Name: Delivery_person_Age, Length: 11399, dtype: float64

# %%
# Descriptive Statistics

df.describe()
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# count         10908.000000             10892.000000         11399.000000
# mean             29.517235                 4.632786            17.099934
# std               5.797077                 0.344081             8.193510
# min              15.000000                 1.000000           -30.902872
# 25%              25.000000                 4.500000            12.933284
# 50%              30.000000                 4.700000            18.551440
# 75%              34.000000                 4.900000            22.732225
# max              50.000000                 6.000000            30.914057
#
#        Restaurant_longitude  Delivery_location_latitude  \
# count          11399.000000                11399.000000
# mean              70.399259                   17.569497
# std               22.773144                    7.287440
# min              -88.400467                    0.010000
# ...

# %%
#shows the informationb about the dataset.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11399 entries, 0 to 11398
# Data columns (total 20 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   ID                                11399 non-null  object
#  1   Delivery_person_ID                11399 non-null  object
#  2   Delivery_person_Age               10908 non-null  float64
#  3   Delivery_person_Ratings           10892 non-null  float64
#  4   Restaurant_latitude               11399 non-null  float64
#  5   Restaurant_longitude              11399 non-null  float64
#  6   Delivery_location_latitude        11399 non-null  float64
#  7   Delivery_location_longitude       11399 non-null  float64
#  8   Order_Date                        11399 non-null  object
#  9   Time_Orderd                       10955 non-null  object
#  10  Time_Order_picked                 11399 non-null  object
# ...

# %%
#Displays the data types of each column.

df.dtypes
# Out:
# ID                                   object
# Delivery_person_ID                   object
# Delivery_person_Age                 float64
# Delivery_person_Ratings             float64
# Restaurant_latitude                 float64
# Restaurant_longitude                float64
# Delivery_location_latitude          float64
# Delivery_location_longitude         float64
# Order_Date                           object
# Time_Orderd                          object
# Time_Order_picked                    object
# Weather                              object
# Road_traffic_density                 object
# Vehicle_condition                     int64
# Type_of_order                        object
# Type_of_vehicle                      object
# multiple_deliveries(yes_1, no_0)    float64
# Festival                             object
# City                                 object
# Name:                                object
# dtype: object

# %%
#shows if there are duplicates in the dataset.

df.duplicated().sum()
# Out:
# 0

# %%
#checking for null values in the dataset

df.isnull().sum()
# Out:
# ID                                    0
# Delivery_person_ID                    0
# Delivery_person_Age                 491
# Delivery_person_Ratings             507
# Restaurant_latitude                   0
# Restaurant_longitude                  0
# Delivery_location_latitude            0
# Delivery_location_longitude           0
# Order_Date                            0
# Time_Orderd                         444
# Time_Order_picked                     0
# Weather                             158
# Road_traffic_density                154
# Vehicle_condition                     0
# Type_of_order                         0
# Type_of_vehicle                       0
# multiple_deliveries(yes_1, no_0)    238
# Festival                             65
# City                                324
# Name:                                 0
# dtype: int64

# %%
#check for unique values in each column.

df.nunique()
# Out:
# ID                                  11399
# Delivery_person_ID                   1297
# Delivery_person_Age                    22
# Delivery_person_Ratings                28
# Restaurant_latitude                   492
# Restaurant_longitude                  434
# Delivery_location_latitude           3572
# Delivery_location_longitude          3572
# Order_Date                             44
# Time_Orderd                           176
# Time_Order_picked                     193
# Weather                                 6
# Road_traffic_density                    4
# Vehicle_condition                       4
# Type_of_order                           4
# Type_of_vehicle                         4
# multiple_deliveries(yes_1, no_0)        4
# Festival                                2
# City                                    3
# Name:                                   1
# dtype: int64

# %%
df.columns
# Out:
# Index(['ID', 'Delivery_person_ID', 'Delivery_person_Age',
#        'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Order_Date', 'Time_Orderd',
#        'Time_Order_picked', 'Weather', 'Road_traffic_density',
#        'Vehicle_condition', 'Type_of_order', 'Type_of_vehicle',
#        'multiple_deliveries(yes_1, no_0)', 'Festival', 'City', 'Name:'],
#       dtype='object')

# %%
#Renaming the column heading that needs renaming or changing.

df = df.rename(columns = ({'Delivery_person_ID' : 'Delivery Person ID', 'Delivery_person_Age' : 'Delivery Person Age',
    'Delivery_person_Ratings' : 'Delivery Person Ratings', 
    'Restaurant_latitude' : 'Restaurant Latitude','Restaurant_longitude' : 'Restaurant Longitude',
    'Delivery_location_latitude' : 'Delivery Location Latitude', 'Delivery_location_longitude' : 'Delivery Location Longitude', 
    'Order_Date' : 'Order Date', 'Time_Orderd' : 'Time Ordered', 'Time_Order_picked' : 'Time Order Picked',
    'Road_traffic_density' : 'Road Traffic Density', 'Vehicle_condition' : 'Vehicle Condition', 'Type_of_order' : 'Type Of Order',
    'Type_of_vehicle' : 'Type Of Vehicle', 'multiple_deliveries(yes_1, no_0)' : 'multiple Deliveries(yes=1, no=0)',  'Name:' : 'Name'}))
df
# Out:
#            ID Delivery Person ID  Delivery Person Age  \
# 0      0x2318    COIMBRES13DEL01                  NaN
# 1      0x3474     BANGRES15DEL01                 28.0
# 2      0x9420      JAPRES09DEL03                 23.0
# 3      0x72ee      JAPRES07DEL03                 21.0
# 4      0xa759     CHENRES19DEL01                 31.0
# ...       ...                ...                  ...
# 11394  0x6909      JAPRES01DEL01                 35.0
# 11395  0x443b      JAPRES11DEL01                 33.0
# 11396  0x1ea5      SURRES11DEL03                  NaN
# 11397  0x22d4      VADRES03DEL02                 27.0
# 11398  0xb7be     CHENRES07DEL02                 39.0
#
#        Delivery Person Ratings  Restaurant Latitude  Restaurant Longitude  \
# 0                          NaN            11.003669             76.976494
# 1                          4.6            12.975377             77.696664
# 2                          4.5            26.911378             75.789034
# ...

# %%
# To see unique values in the column

df['Type Of Vehicle'].unique()
# Out:
# array(['electric_scooter', 'motorcycle', 'scooter', 'bicycle'],
#       dtype=object)

# %%
#Drops column that isnt relevant to the dataset because its null values exceeds 80% of that column.

df = df.drop(columns = 'Name')
df
# Out:
#            ID Delivery Person ID  Delivery Person Age  \
# 0      0x2318    COIMBRES13DEL01                  NaN
# 1      0x3474     BANGRES15DEL01                 28.0
# 2      0x9420      JAPRES09DEL03                 23.0
# 3      0x72ee      JAPRES07DEL03                 21.0
# 4      0xa759     CHENRES19DEL01                 31.0
# ...       ...                ...                  ...
# 11394  0x6909      JAPRES01DEL01                 35.0
# 11395  0x443b      JAPRES11DEL01                 33.0
# 11396  0x1ea5      SURRES11DEL03                  NaN
# 11397  0x22d4      VADRES03DEL02                 27.0
# 11398  0xb7be     CHENRES07DEL02                 39.0
#
#        Delivery Person Ratings  Restaurant Latitude  Restaurant Longitude  \
# 0                          NaN            11.003669             76.976494
# 1                          4.6            12.975377             77.696664
# 2                          4.5            26.911378             75.789034
# ...

# %%
# Converting date column to normal date format

df['Order Date'] = pd.to_datetime(df['Order Date'], errors='coerce')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_19940\2528406117.py:3: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Order Date'] = pd.to_datetime(df['Order Date'], errors='coerce')

# %%
df
# Out:
#            ID Delivery Person ID  Delivery Person Age  \
# 0      0x2318    COIMBRES13DEL01                  NaN
# 1      0x3474     BANGRES15DEL01                 28.0
# 2      0x9420      JAPRES09DEL03                 23.0
# 3      0x72ee      JAPRES07DEL03                 21.0
# 4      0xa759     CHENRES19DEL01                 31.0
# ...       ...                ...                  ...
# 11394  0x6909      JAPRES01DEL01                 35.0
# 11395  0x443b      JAPRES11DEL01                 33.0
# 11396  0x1ea5      SURRES11DEL03                  NaN
# 11397  0x22d4      VADRES03DEL02                 27.0
# 11398  0xb7be     CHENRES07DEL02                 39.0
#
#        Delivery Person Ratings  Restaurant Latitude  Restaurant Longitude  \
# 0                          NaN            11.003669             76.976494
# 1                          4.6            12.975377             77.696664
# 2                          4.5            26.911378             75.789034
# ...

# %%
df_dropped = df.dropna()
df = df_dropped

# %%
# Resetting the index

df_reset = df_dropped.reset_index(drop=True)

# %%
df = df_reset

# %%
df
# Out:
#           ID Delivery Person ID  Delivery Person Age  Delivery Person Ratings  \
# 0     0x3474     BANGRES15DEL01                 28.0                      4.6
# 1     0xa759     CHENRES19DEL01                 31.0                      4.6
# 2     0xc4af      GOARES04DEL01                 26.0                      4.7
# 3     0xdd42      KOLRES06DEL02                 26.0                      4.8
# 4     0xd845      KOCRES09DEL01                 24.0                      4.8
# ...      ...                ...                  ...                      ...
# 5597  0x9d1f      JAPRES19DEL03                 38.0                      4.0
# 5598  0xd3de     LUDHRES07DEL03                 26.0                      4.8
# 5599  0xe240      BHPRES07DEL01                 31.0                      4.7
# 5600  0x6909      JAPRES01DEL01                 35.0                      4.6
# 5601  0xb7be     CHENRES07DEL02                 39.0                      5.0
#
# ...

# %%
df['Time Ordered'] = pd.to_datetime(df['Order Date'].astype(str) +' ' + df['Time Ordered'].astype(str), errors='coerce')
df['Time Order Picked'] = pd.to_datetime(df['Order Date'].astype(str) +' ' + df['Time Order Picked'].astype(str), errors='coerce')
df['Delivery_time'] = (df['Time Order Picked'] - df['Time Ordered']).dt.total_seconds() /60

# %%
df
# Out:
#           ID Delivery Person ID  Delivery Person Age  Delivery Person Ratings  \
# 0     0x3474     BANGRES15DEL01                 28.0                      4.6
# 1     0xa759     CHENRES19DEL01                 31.0                      4.6
# 2     0xc4af      GOARES04DEL01                 26.0                      4.7
# 3     0xdd42      KOLRES06DEL02                 26.0                      4.8
# 4     0xd845      KOCRES09DEL01                 24.0                      4.8
# ...      ...                ...                  ...                      ...
# 5597  0x9d1f      JAPRES19DEL03                 38.0                      4.0
# 5598  0xd3de     LUDHRES07DEL03                 26.0                      4.8
# 5599  0xe240      BHPRES07DEL01                 31.0                      4.7
# 5600  0x6909      JAPRES01DEL01                 35.0                      4.6
# 5601  0xb7be     CHENRES07DEL02                 39.0                      5.0
#
# ...

# %%
df_dropped = df.dropna()
df = df_dropped

# %%
df[['Time Ordered', 'Time Order Picked', 'Delivery_time']]
# Out:
#             Time Ordered   Time Order Picked  Delivery_time
# 0    2022-03-29 20:30:00 2022-03-29 20:35:00            5.0
# 1    2022-03-27 18:25:00 2022-03-27 18:40:00           15.0
# 2    2022-02-15 09:45:00 2022-02-15 09:55:00           10.0
# 4    2022-02-17 14:35:00 2022-02-17 14:40:00            5.0
# 5    2022-03-16 23:40:00 2022-03-16 23:55:00           15.0
# ...                  ...                 ...            ...
# 5596 2022-03-19 17:35:00 2022-03-19 17:45:00           10.0
# 5597 2022-03-24 21:30:00 2022-03-24 21:45:00           15.0
# 5598 2022-02-15 23:10:00 2022-02-15 23:20:00           10.0
# 5600 2022-03-27 21:35:00 2022-03-27 21:45:00           10.0
# 5601 2022-03-24 22:20:00 2022-03-24 22:25:00            5.0
#
# [4550 rows x 3 columns]

# %%
df['Delivery_time'].describe()
# Out:
# count    4550.000000
# mean       10.052747
# std         4.072257
# min         5.000000
# 25%         5.000000
# 50%        10.000000
# 75%        15.000000
# max        15.000000
# Name: Delivery_time, dtype: float64

# %%
# will turn time ordered an tine ordered picked to Na values
df['Time Ordered'] = pd.to_datetime(df['Time Ordered'], format = '%I:%M', errors='coerce').dt.time
df['Time Order Picked'] = pd.to_datetime(df['Time Order Picked'], format = '%I:%M', errors='coerce').dt.time
df
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_19940\3989628277.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Time Ordered'] = pd.to_datetime(df['Time Ordered'], format = '%I:%M', errors='coerce').dt.time
# C:\Users\user\AppData\Local\Temp\ipykernel_19940\3989628277.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Time Order Picked'] = pd.to_datetime(df['Time Order Picked'], format = '%I:%M', errors='coerce').dt.time
# ...

# %%
df_reset = df_dropped.reset_index(drop=True)
df = df_reset
df
# Out:
#           ID Delivery Person ID  Delivery Person Age  Delivery Person Ratings  \
# 0     0x3474     BANGRES15DEL01                 28.0                      4.6
# 1     0xa759     CHENRES19DEL01                 31.0                      4.6
# 2     0xc4af      GOARES04DEL01                 26.0                      4.7
# 3     0xd845      KOCRES09DEL01                 24.0                      4.8
# 4     0xbd51     BANGRES11DEL01                 33.0                      4.8
# ...      ...                ...                  ...                      ...
# 4545  0x1e46      HYDRES01DEL03                 21.0                      5.0
# 4546  0x9d1f      JAPRES19DEL03                 38.0                      4.0
# 4547  0xd3de     LUDHRES07DEL03                 26.0                      4.8
# 4548  0x6909      JAPRES01DEL01                 35.0                      4.6
# 4549  0xb7be     CHENRES07DEL02                 39.0                      5.0
#
# ...

# %%
traffic_impact = df.groupby('Road Traffic Density')['Delivery_time'].describe()

# %%
traffic_impact
# Out:
#                        count       mean       std  min  25%   50%   75%   max
# Road Traffic Density
# High                   493.0   9.918864  4.094105  5.0  5.0  10.0  15.0  15.0
# Jam                   1422.0  10.214487  4.084745  5.0  5.0  10.0  15.0  15.0
# Low                   1496.0   9.913102  4.059648  5.0  5.0  10.0  15.0  15.0
# Medium                1139.0  10.092186  4.060756  5.0  5.0  10.0  15.0  15.0

# %%
sns.boxplot(x='Road Traffic Density', y='Delivery_time', data=df)
plt.title('Impact of Traffic Density on Delivery Time')
plt.show()

# %%
weather_effect = df.groupby('Weather')['Delivery_time'].agg(['mean', 'std', 'count']).reset_index()
weather_effect
# Out:
#       Weather       mean       std  count
# 0      Cloudy  10.243902  4.032907    779
# 1         Fog  10.049226  4.028643    711
# 2  Sandstorms   9.804046  4.016521    791
# 3      Stormy  10.108382  4.073648    692
# 4       Sunny   9.929757  4.104008    783
# 5       Windy  10.188917  4.167318    794

# %%
from scipy import stats
groups = [df[df['Weather'] == w]['Delivery_time'].dropna() for w in df['Weather'].unique()]
stats, p_value = stats.f_oneway(*groups)
print(f'ANOVA Test: F-statistic =p-value = {p_value}')
if p_value < 0.05:
    print('Weather conditions significantly impact delivery time')
else:
    print('No significant effect of weather on delivery time')
# Out:
# ANOVA Test: F-statistic =p-value = 0.2693909465881314
# No significant effect of weather on delivery time

# %%
plt.figure(figsize=(10,4))
sns.boxplot(x='Delivery Person Ratings', y='Delivery_time', data=df, palette='coolwarm')
plt.title('Effect of Delivery Personnel Ratings on Delivery_time')
plt.xlabel('Delivery Person Ratings')
plt.ylabel('Delivery_time')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x='Delivery Person Age', y='Delivery_time', data=df)
plt.title('Effect of Delivery Personnel Age on Delivery Time')
plt.xlabel('Delivery Person Age')
plt.ylabel('Delivery_time')
plt.show()

# %%
from scipy.stats import pearsonr

# %%
corr_age, p_age = pearsonr(df['Delivery Person Age'], df['Delivery_time'])
print(f'correlation between Age and Delivery time: {corr_age}, p-value: {p_age}')

corr_ratings, p_ratings = pearsonr(df['Delivery Person Ratings'], df['Delivery_time'])
print(f'correlation between Ratings and Delivery time: {corr_ratings}, p-value: {p_ratings}')
# Out:
# correlation between Age and Delivery time: -0.00309266734170603, p-value: 0.83479564444089
# correlation between Ratings and Delivery time: 0.016366264505905812, p-value: 0.2697078963168168

# %%
from scipy import stats

# %%
festival_effect = df.groupby('Festival')['Delivery_time'].agg(['mean', 'std', 'count']).reset_index()
festival_effect
# Out:
#   Festival       mean       std  count
# 0       No  10.047054  4.069381   4463
# 1      Yes  10.344828  4.231190     87

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x='Festival', y='Delivery_time', data=df, palette='coolwarm')
plt.title('Order Volume During Festivals Vs Non-Festivals')
plt.xlabel('Festival')
plt.ylabel('Delivery Time')
plt.show()

# %%
order_counts = df['Festival'].value_counts()
plt.figure(figsize=(6,4))
sns.barplot(x=order_counts.index, y=order_counts.values, palette='magma')
plt.title('Order Volume During Festivals Vs Non-Festivals')
plt.xlabel('Festival')
plt.ylabel('Number of Orders')
plt.show()

# %%
festival_times = df[df['Festival'] == 'Yes']['Delivery_time'].dropna()
non_festival_times = df[df['Festival'] =='No']['Delivery_time'].dropna()

# %%
t_stat, p_value = stats.ttest_ind(festival_times, non_festival_times, equal_var=False)
print(f'T-test: t-statistic = {t_stat}, p_value = {p_value}')
# Out:
# T-test: t-statistic = 0.6505840399298146, p_value = 0.5169886567014957

# %%
if p_value < 0.05:
    print('Significant difference in delivery times during festivals')
else:
    print('No significant difference in delivery times during festivals')
# Out:
# No significant difference in delivery times during festivals

# %%
plt.figure(figsize = (10,6))
sns.scatterplot(x=df['Delivery Location Longitude'],y=df['Delivery Location Latitude'], alpha=0.5)
plt.title('Delivery Locations (Latitude Vs Longitude)')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %%
vehicle_effect = df.groupby('Vehicle Condition')['Delivery_time'].agg(['mean', 'std', 'count'])
vehicle_effect
# Out:
#                         mean       std  count
# Vehicle Condition
# 0                  10.060647  4.047471   1484
# 1                  10.036376  4.113946   1512
# 2                  10.061133  4.057633   1554

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x='Vehicle Condition', y='Delivery_time', data=df, palette='coolwarm')
plt.title('Effect of Vehicle condition on Dellivery Time')
plt.xlabel('Vehicle Condition')
plt.ylabel('Delivery Time')
plt.show()

# %%
vehicle_groups = [df[df['Vehicle Condition'] ==v]['Delivery_time'].dropna() for v in df['Vehicle Condition'].unique()]
anova_stat, p_value = stats.f_oneway(*vehicle_groups)

# %%
print(f'ANOVA Test: F-statistic = {anova_stat}, p-value = {p_value}')
# Out:
# ANOVA Test: F-statistic = 0.018297737289702857, p-value = 0.9818687222204159

# %%
if p_value < 0.05:
    print('vehicle condition significantly impacts delivery time')
else:
    print('No significant impact of vehicle conditions on delivery time')
# Out:
# No significant impact of vehicle conditions on delivery time
